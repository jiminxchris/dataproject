# %%
# 가상환경 만들기
python -m venv dataproject

# 가상환경 진입하기
C:\Users\chrisLin\Desktop\dataprojects\venvs\dataproject\Scripts> activate

# 모듈 설치하기
(dataproject) C:\Users\chrisLin\Desktop\dataprojects\pip install ipykernel

# 가상환경을 jupyther notebook 환경에서 선택가능한 커널로 등록하기
(dataproject) C:\Users\chrisLin\Desktop\dataprojects\python -m ipykernel install --user --name myproject --display-name "Python (dataproject)"

# 가상환경 선택하기(둘 중 아무거나)

# %%
# %pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.1
# colorama                0.4.6
# comm                    0.2.3
# debugpy                 1.8.19
# decorator               5.2.1
# executing               2.2.1
# ipykernel               7.1.0
# ipython                 9.9.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# jupyter_client          8.8.0
# jupyter_core            5.9.1
# matplotlib-inline       0.2.1
# nest-asyncio            1.6.0
# packaging               26.0
# parso                   0.8.5
# pip                     24.0
# platformdirs            4.5.1
# prompt_toolkit          3.0.52
# psutil                  7.2.2
# pure_eval               0.2.3
# Pygments                2.19.2
# python-dateutil         2.9.0.post0
# pyzmq                   27.1.0
# setuptools              65.5.0
# six                     1.17.0
# stack-data              0.6.3
# tornado                 6.5.4
# ...

# %%
print('Hello python')
# Out:
# Hello python

# %%
# %pip install psycopg2-binary

# %%
import psycopg2

# %%
# %pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.1
# colorama                0.4.6
# comm                    0.2.3
# debugpy                 1.8.19
# decorator               5.2.1
# executing               2.2.1
# ipykernel               7.1.0
# ipython                 9.9.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# jupyter_client          8.8.0
# jupyter_core            5.9.1
# matplotlib-inline       0.2.1
# nest-asyncio            1.6.0
# packaging               26.0
# parso                   0.8.5
# pip                     24.0
# platformdirs            4.5.1
# prompt_toolkit          3.0.52
# psutil                  7.2.2
# psycopg2-binary         2.9.11
# pure_eval               0.2.3
# Pygments                2.19.2
# python-dateutil         2.9.0.post0
# pyzmq                   27.1.0
# setuptools              65.5.0
# six                     1.17.0
# stack-data              0.6.3
# ...
